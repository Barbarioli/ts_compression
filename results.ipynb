# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ## Metro_Interstate_Traffic_Volume

# %% [markdown]
# ###VQ-VAE

# %%
compression_2d_vqvae = [0.006, 0.00305,0.001483,0.00077,0.00042,0.00024,0.00016]
compression_2d_vqvae_log = np.log10([0.006,0.00305,0.001483,0.00077,0.00042,0.00024,0.00016])
n_used_embeddings = [204, 107, 64, 30, 16, 8,4 ]
n_embeddings = [256, 128, 64, 30, 16, 8,4 ]
reconstruction_error_1_vqvae = [0.3495, 0.237, 0.40, 0.6201, 0.24,0.2456, 0.521]
reconstruction_error_2_vqvae = [97.04, 308.54, 323.644,103.52,72.27, 316.27, 174.33]
reconstruction_error_3_vqvae = [3.3152, 2.05, 2.44, 2.56, 1.187, 1.2871, 1.3668]
reconstruction_error_4_vqvae = [0.5476, 0.555, 0.418, 0.2839, 0.051, 0.4429, 0.54799]
training_time = [240,240,156, 168, 168,240]

# %%
compression_1d_vqvae = [0.0017,0.0017, 0.000974, 0.00097, 0.00064]
compression_1d_vqvae_log = np.log10([0.0017,0.0017, 0.000974, 0.00097, 0.00064])
n_used_embeddings_1d = [20,16, 10, 7, 4]
n_embeddings_1d = [64,32, 16, 8, 4]
reconstruction_error_1_1d_vqvae = [0.068899,0.04456, 0.05, 0.047, 0.04756]
#reconstruction_error_1_1d_vqvae_log = np.log10([0.068899,0.04456, 0.05, 0.047, 0.04756])

# %%
plt.plot(n_embeddings, compression_2d_vqvae)
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.xlim(max(n_embeddings), min(n_embeddings))
plt.title('2D: Compression ratio x Number of embeddings')
plt.ylabel('Compression ratio')
plt.xlabel('Number of embeddings')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 0, 'Number of embeddings')

# %%
# emb_dim = 8 
#n_embeddings = [128, 64, 32, 16, 8]
#n_used_embeddings = [1, 1, 1, 1, 1]
plt.plot(n_embeddings, n_used_embeddings, label = "Used")
plt.plot(n_embeddings, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.title('2D: Used x total embeddings')
plt.ylabel('Number of embeddings used')
plt.xlabel('Number of embeddings in the model')
# Out:
# Text(0.5, 0, 'Number of embeddings in the model')

# %%
plt.plot(n_embeddings_1d, compression_1d_vqvae)
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.xlim(max(n_embeddings_1d), min(n_embeddings_1d))
plt.title('1D: Compression ratio x Number of embeddings')
plt.ylabel('Compression ratio')
plt.xlabel('Number of embeddings')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 0, 'Number of embeddings')

# %%
# emb_dim = 8 
#n_embeddings = [128, 64, 32, 16, 8]
#n_used_embeddings = [1, 1, 1, 1, 1]
plt.plot(n_embeddings_1d, n_used_embeddings_1d, label = "Used")
plt.plot(n_embeddings_1d, n_embeddings_1d, color = 'red', label = 'Maximum')
plt.legend()
plt.title('1D: Used x total embeddings')
plt.ylabel('Number of embeddings used')
plt.xlabel('Number of embeddings in the model')
# Out:
# Text(0.5, 0, 'Number of embeddings in the model')

# %%
# varying time step window
# time steps = 256
new_data = [1,5,10,32,128]
recon_error = [0.093,0.5987, 0.9982, 0.9961, 0.996]
compression = [0.0097,0.0017,0.00064,0.00064, 0.00064]
n_embeddings_used = [20,8,5,4,2]
plt.plot(new_data, compression)
#plt.plot(n_embeddings_1d, n_embeddings_1d, color = 'red', label = 'Maximum')
#plt.legend()
plt.title('Overlapping window x compression ratio')
plt.ylabel('Compression')
plt.xlabel('New data')
# Out:
# Text(0.5, 0, 'New data')

# %%
plt.plot(new_data, n_embeddings_used)
#plt.plot(n_embeddings_1d, n_embeddings_1d, color = 'red', label = 'Maximum')
#plt.legend()
plt.title('Overlapping window x embeddings')
plt.ylabel('Used embeddings')
plt.xlabel('New data')
# Out:
# Text(0.5, 0, 'New data')

# %%
plt.plot(new_data, recon_error)
#plt.plot(n_embeddings_1d, n_embeddings_1d, color = 'red', label = 'Maximum')
#plt.legend()
plt.title('Overlapping window x recon_error')
plt.ylabel('Error')
plt.xlabel('New data')
# Out:
# Text(0.5, 0, 'New data')

# %%
#increasing time window
window_size = [1024, 256,64, 32]
compression = [0.00097,0.0017,0.0017, 0.00097]
recon_error = [0.62,0.093,0.05,0.037]
n_embeddings_used = [9,20,10,7]
plt.plot(window_size, n_embeddings_used)
#plt.plot(n_embeddings_1d, n_embeddings_1d, color = 'red', label = 'Maximum')
#plt.legend()
plt.title('window size x embeddings')
plt.ylabel('Used embeddings')
plt.xlabel('window')
# Out:
# Text(0.5, 0, 'window')

# %%
plt.plot(window_size, compression)
#plt.plot(n_embeddings_1d, n_embeddings_1d, color = 'red', label = 'Maximum')
#plt.legend()
plt.title('window size x compression')
plt.ylabel('Used compression')
plt.xlabel('window')
# Out:
# Text(0.5, 0, 'window')

# %%
plt.plot(window_size, recon_error)
#plt.plot(n_embeddings_1d, n_embeddings_1d, color = 'red', label = 'Maximum')
#plt.legend()
plt.title('window size x error')
plt.ylabel('error')
plt.xlabel('window')
# Out:
# Text(0.5, 0, 'window')

# %% [markdown]
# ## PCA

# %%
#train
compression_pca = [0.25, 0.5, 0.75]
compression_pca_log = np.log10([0.25, 0.5, 0.75])
reconstruction_error_1_pca = [0.047, 0.046, 0]
reconstruction_error_2_pca = [7.8689, 7.8437,7.80]
reconstruction_error_3_pca = [0.7886, 0.01139, 0]
reconstruction_error_4_pca = [0.000016, 0,0]
time = [0,0,0]

# %% [markdown]
# ###DFT

# %%
#train
compression_dft = [0.0001, 0.001, 0.01, 0.25, 0.50, 0.75]
compression_dft_log = np.log10([0.0001, 0.001, 0.01, 0.25, 0.50, 0.75])
compression_dft_part_1 = [0.0001, 0.001, 0.01]
compression_dft_part_2 = [0.25, 0.50, 0.75]
reconstruction_error_1_dft = [0.287	, 0.680981, 0.474615, 0.19287, 0.090485, 0.171169]
reconstruction_error_1_dft_part1 = [0.287	, 0.680981, 0.474615]
reconstruction_error_1_dft_part2 = [0.19287, 0.090485, 0.171169]
reconstruction_error_2_dft = [1117.725, 1465.457084,1633.852179, 397.222018, 193.545948, 372.60734]
reconstruction_error_3_dft = [1.794, 3.9501, 2.770484, 1.102274, 0.515474, 0.979624]
reconstruction_error_4_dft = [0.588, 0.530973,0.396165, 0.031925, 0.007806, 0.031591]
time = [0,0,0,0,0,0]

# %% [markdown]
# # Temperature

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.plot(compression_2d_vqvae, reconstruction_error_1_vqvae, label = 'vqvae')
plt.plot(compression_pca, reconstruction_error_1_pca, label = 'pca')
plt.plot(compression_dft, reconstruction_error_1_dft, label = 'dft')
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.title('Temperature')
plt.ylabel('Reconstruction error')
plt.xlabel('Compression ratio')
# Out:
# Text(0.5, 0, 'Compression ratio')

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.plot(compression_2d_vqvae, reconstruction_error_1_vqvae, label = 'vqvae')
#plt.plot(compression_pca, reconstruction_error_1_pca, label = 'pca')
plt.plot(compression_dft_part_1, reconstruction_error_1_dft_part1, label = 'dft')
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.title('Temperature')
plt.ylabel('Reconstruction error')
plt.xlabel('Compression ratio')
# Out:
# Text(0.5, 0, 'Compression ratio')

# %%
plt.figure(figsize=(15, 5), dpi=80)
#plt.plot(compression_2d_vqvae, reconstruction_error_1_vqvae, label = 'vqvae')
plt.plot(compression_pca, reconstruction_error_1_pca, label = 'pca')
plt.plot(compression_dft_part_2, reconstruction_error_1_dft_part2, label = 'dft')
plt.legend()
plt.title('Temperature')
plt.ylabel('Reconstruction error')
plt.xlabel('Compression ratio')
# Out:
# Text(0.5, 0, 'Compression ratio')

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.plot(compression_2d_vqvae_log, reconstruction_error_1_vqvae, label = 'vqvae')
plt.plot(compression_pca_log, reconstruction_error_1_pca, label = 'pca')
plt.plot(compression_dft_log, reconstruction_error_1_dft, label = 'dft')
plt.plot(compression_1d_vqvae_log, reconstruction_error_1_1d_vqvae, label = 'vqvae 1d')
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.title('Temperature')
plt.ylabel('Reconstruction error')
plt.xlabel('Compression ratio(log scale)')
# Out:
# Text(0.5, 0, 'Compression ratio(log scale)')

# %% [markdown]
# ## Rain

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.plot(compression_2d_vqvae, reconstruction_error_2_vqvae, label = 'vqvae')
plt.plot(compression_pca, reconstruction_error_2_pca, label = 'pca')
plt.plot(compression_dft, reconstruction_error_2_dft, label = 'dft')
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.title('Rain')
plt.ylabel('Reconstruction error')
plt.xlabel('Compression ratio')
# Out:
# Text(0.5, 0, 'Compression ratio')

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.plot(compression_2d_vqvae, reconstruction_error_3_vqvae, label = 'vqvae')
plt.plot(compression_pca, reconstruction_error_3_pca, label = 'pca')
plt.plot(compression_dft, reconstruction_error_3_dft, label = 'dft')
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.title('Clouds')
plt.ylabel('Reconstruction error')
plt.xlabel('Compression ratio')
# Out:
# Text(0.5, 0, 'Compression ratio')

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.plot(compression_2d_vqvae, reconstruction_error_4_vqvae, label = 'vqvae')
plt.plot(compression_pca, reconstruction_error_4_pca, label = 'pca')
plt.plot(compression_dft, reconstruction_error_4_dft, label = 'dft')
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.title('Traffic')
plt.ylabel('Reconstruction error')
plt.xlabel('Compression ratio')
# Out:
# Text(0.5, 0, 'Compression ratio')

# %% [markdown]
# # 1D with overfitting and variable window

# %%
original_sample = 48204
compressed_sample = [48, 93, 187, 375, 752, 1505, 3011, 6024]
percentage_sample = np.array(compressed_sample)/original_sample
reconstruction_error = [0.401,0.152,0.044,0.045,0.046,0.05,0.045,0.045]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_dpi(128)
fig.set_figwidth(10)
fig.set_figheight(2.5)
fig.suptitle('Reconstruction errors vs samples')
ax1.plot(compressed_sample, reconstruction_error, '.-')
ax1.set_ylabel('Reconstruction error')
ax1.set_xlabel('Compressed')
ax2.plot(percentage_sample, reconstruction_error, '.-', color = 'r')
ax2.set_ylabel('Reconstruction error')
ax2.set_xlabel('Percentage sample')
# Out:
# Text(0.5, 0, 'Percentage sample')

# %%
#commitment cost = 10
#compressed sample = 48
alpha = [1,1.25, 1.5,1.75, 2,2.5, 5]
reconstruction_error = [0.401,0.4218,0.2256,0.431644, 0.297,0.3057 ,0.4039]

# %%
#alpha = 1.75
#compressed sample = 48
beta = [1,2.5,7.5,10]
reconstruction_error_b = [0.0935,0.071,0.059,0.086]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_dpi(128)
fig.set_figwidth(10)
fig.set_figheight(2.5)
fig.suptitle('Alpha and Beta vs reconstruction error')
ax1.plot(alpha, reconstruction_error, '.-')
ax1.set_ylabel('Reconstruction error')
ax1.set_xlabel('alpha')
#ax1.set_label('Beta = 10')
ax2.plot(beta, reconstruction_error_b, '.-', color = 'r')
ax2.set_ylabel('Reconstruction error')
ax2.set_xlabel('beta')
# Out:
# Text(0.5, 0, 'beta')

# %%
vq_vae_compression = np.log([0.0297,0.0164, 0.0074,0.0014,0.0012])
vq_vae_reconstruction = [0.034,0.033, 0.035, 0.0391,0.038]
dff_compression = np.log([0.75, 0.5, 0.25, 0.01])
dff_reconstruction = [0.049, 0.073, 0.099, 0.1915]
reconstruction_error_1_pca = [0.047, 0.046, 0]
pca_compression = np.log([0.25, 0.5, 0.75])

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.plot(vq_vae_compression, vq_vae_reconstruction, label = 'vqvae')
plt.plot(pca_compression, reconstruction_error_1_pca, label = 'pca')
plt.plot(dff_compression, dff_reconstruction, label = 'dft')
#plt.plot(commitment_cost, n_embeddings, color = 'red', label = 'Maximum')
plt.legend()
plt.title('Temperature')
plt.ylabel('Reconstruction error')
plt.xlabel('Compression ratio(log scale)')
# Out:
# Text(0.5, 0, 'Compression ratio(log scale)')

# %%
kernel_size = [1,3,7,12]
reconstruction_error = [0.2998,0.4584,0.04, 0.299]
compression_ratio = [0.00116, 0.00116,0.00116, 0.00116]
compression_ratio_with_model = [29.19, 87.2323,201.66, 348]
compression_pandas = []

strides = [2, 4, 6]
reconstruction_error_s = [0.04,0.038,0.04]
compression_ratio = [0.00116, 0.00063, 0.00083]
compression_ratio_with_model = [201.66, 203.30,203.30]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_dpi(128)
fig.set_figwidth(12)
fig.set_figheight(2.5)
fig.suptitle('Kernel and Stride vs reconstruction error')
ax1.plot(kernel_size, reconstruction_error, '.-')
ax1.set_ylabel('Reconstruction error')
ax1.set_xlabel('kernel size')
#ax1.set_label('Beta = 10')
ax2.plot(strides, reconstruction_error_s, '.-', color = 'r')
ax2.set_ylabel('Reconstruction error')
ax2.set_xlabel('stride')
# Out:
# Text(0.5, 0, 'stride')

# %%
#dense = 0.038
